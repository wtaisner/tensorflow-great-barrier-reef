# %%
import wandb
# !wandb login 71c91f3a4c5670f61ec1d28a9ee92e8199480dc8

# %%
import os, shutil
def copytree(src, dst, symlinks=False, ignore=None):
    for item in os.listdir(src):
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        if os.path.isdir(s):
            shutil.copytree(s, d, symlinks, ignore)
        else:
            shutil.copy2(s, d)

saved_path = "/kaggle/input/apyolo"  # The path of your old data, which you have uploaded to new kernal as input
output_path = "/kaggle/working/"  # The output path of your new kernel.

copytree(saved_path, output_path)

# %%
# %cd

# %%
config = {
'path': '/kaggle/input/k/annprzyb/data-augmentation/data',
'train': 'images/train',
'val': 'images/val',
'test': 'images/test',
'nc': 1,
'names': ['starfish']
}

# %%
import yaml
with open("/kaggle/working/data_yolo.yaml", "w") as file:
    yaml.dump(config, file, default_flow_style=False)

# %%
# %cd /kaggle/working/yolov5

# %%
# !python train.py --epochs 5 --data ../data_yolo.yaml --weights yolov5m.pt --evolve 10 --project "great-barrier-reef" --name "yolo_evolve" --entity "ap-wt"
