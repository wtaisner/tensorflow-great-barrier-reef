# %%
import wandb
# !wandb login 1af1acbce3feeccf78856c5fa6c11c79c791ee85
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !ls /kaggle/input
# Out:
# apyolo	k

# %%
import os, shutil
def copytree(src, dst, symlinks=False, ignore=None):
    for item in os.listdir(src):
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        if os.path.isdir(s):
            shutil.copytree(s, d, symlinks, ignore)
        else:
            shutil.copy2(s, d)

saved_path = "/kaggle/input/apyolo"  # The path of your old data, which you have uploaded to new kernal as input
output_path = "/kaggle/working/"  # The output path of your new kernel.

copytree(saved_path, output_path)

# %%
# %cd
# Out:
# /root

# %%
config = {
'path': '/kaggle/input/k/annprzyb/data-augmentation/data',
'train': 'images/train',
'val': 'images/val',
'test': 'images/test',
'nc': 1,
'names': ['starfish']
}

# %%
import yaml
with open("/kaggle/working/data_yolo.yaml", "w") as file:
    yaml.dump(config, file, default_flow_style=False)

# %%
# %cd /kaggle/working/yolov5
# Out:
# /kaggle/working/yolov5

# %%
# !python train.py --epochs 15 --data ../data_yolo.yaml --weights yolov5m.pt --project "great-barrier-reef" --name "yolo_medium_default" --entity "ap-wt"
# Out:
# ...
# wandb: Currently logged in as: ap-wt (use `wandb login --relogin` to force relogin)
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Total 77 (delta 54), reused 54 (delta 54), pack-reused 23
# Unpacking objects: 100% (77/77), 20.99 KiB | 693.00 KiB/s, done.
# From https://github.com/ultralytics/yolov5
#    16563ac..3b7ac28  master             -> origin/master
#  * [new branch]      fix/multi_gpu      -> origin/fix/multi_gpu
#  * [new branch]      updates/benchmarks -> origin/updates/benchmarks
# github: ⚠️ YOLOv5 is out of date by 3 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# wandb: wandb version 0.12.9 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.7
# wandb: Syncing run yolo_medium_default
# wandb: ⭐️ View project at https://wandb.ai/ap-wt/great-barrier-reef
# ...
